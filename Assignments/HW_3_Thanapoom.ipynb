# %% [markdown]
# # HW3: Natural Language Processing

# %% [markdown]
# **Instructions**:
# - Please read the problem description carefully
# - Make sure to complete all requirements (shown as bullets) . In general, it would be much easier if you complete the requirements in the order as shown in the problem description
# - Follow the Submission Instruction to submit your assignment.
# - Code of academic integrity:
#     - **Each assignment needs to be completed independently. This is NOT group assignment**.
#     - Never ever copy others' work (even with minor modification, e.g. changing variable names)
#     - If you generate code using large lanaguage models (although it is not encouraged), make sure to adapt the generated code to meet all requirements and it is executable.
#     - Anti-Plagiarism software will be used to check similarities between all submissions.
#     - Check Syllabus for more details.

# %% [markdown]
# ## Q1: Extract data using regular expression (2 points)
# Suppose you have scraped the text shown below from an online source (https://finance.yahoo.com/). Write `a single regular expression` to covert the text into a list of tuples `(Symbol, Last Price, Change, % Change)` as shown below.

# %%
pip install spacy
# Out:
# Requirement already satisfied: spacy in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from spacy) (4.64.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.28.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.6.1)
# Requirement already satisfied: jinja2 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from spacy) (2.11.3)
# Requirement already satisfied: setuptools in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from spacy) (63.4.1)
# Requirement already satisfied: packaging>=20.0 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from spacy) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from spacy) (1.24.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.16.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.9.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.24)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/thanapoomphatthanaphan/opt/anaconda3/lib/python3.9/site-packages (from jinja2->spacy) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import nltk
from sklearn.metrics import pairwise_distances
import numpy as np
from matplotlib import pyplot as plt
from sklearn.preprocessing import normalize
import re
import json
import pprint as pp
import spacy
from collections import defaultdict

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# !python3 -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 3.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.29.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.6.1)
# Requirement already satisfied: jinja2 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (67.8.0)
# Requirement already satisfied: packaging>=20.0 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.2 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
text='''BTC-USD

Bitcoin USD
	63,473.52	+1,498.26	+2.42%
ETH-USD

Ethereum USD
	3,471.85	+39.03	+1.14%
USDT-USD

Tether USDt USD
	1.00	-0.00	-0.01%
BNB-USD

BNB USD
	414.75	+4.12	+1.00%
SOL-USD

Solana USD
	128.86	-1.31	-1.01%'''

# %%
result = re.findall(r'(\w+-\w+\s+.*\s)\s([\d,]+\.\d+)\s([\d,+-]+\.\d+)\s([\d+-.%]+)', text)
pp.pprint(result)
# Out:
# [('BTC-USD\n\nBitcoin USD\n', '63,473.52', '+1,498.26', '+2.42%'),
#  ('ETH-USD\n\nEthereum USD\n', '3,471.85', '+39.03', '+1.14%'),
#  ('USDT-USD\n\nTether USDt USD\n', '1.00', '-0.00', '-0.01%'),
#  ('BNB-USD\n\nBNB USD\n', '414.75', '+4.12', '+1.00%'),
#  ('SOL-USD\n\nSolana USD\n', '128.86', '-1.31', '-1.01%')]

# %% [markdown]
# ## Q2: Develop a QA system (8 points)
#
#
# Objective: Find a sentence in an article that can best answer a question. A dataset has been provided. Please follow the instruction below carefully to develop this system.

# %%
data = json.load(open("qa.json", "r"))
data[5]
# Out:
# {'text': 'In 1995, Coolio made a song featuring R&B singer LV for the movie Dangerous Minds, titled "Gangsta\'s Paradise". It would become one of the most successful rap songs of all time, reaching #1 on the Billboard Hot 100 for 3 weeks. It was the #1 single of 1995 for all genres, and was a global hit, as it reached #1 in the United States, United Kingdom, Ireland, France, Germany, Italy, Sweden, Austria, Netherlands, Norway, Switzerland, Australia, and New Zealand. The song also created a controversy when Coolio claimed that parody artist "Weird Al" Yankovic had not asked for permission to make his parody of "Gangsta\'s Paradise", titled "Amish Paradise". At the 1996 Grammy Awards, the song won Coolio a Grammy for Best Rap Solo Performance.  Originally "Gangsta\'s Paradise" was not meant to be included on one of Coolio\'s studio albums, but its success led to Coolio not only putting it on his next album but also making it the title track. The title track sampled the chorus and music of the song "Pastime Paradise" by Stevie Wonder, which was recorded nearly 20 years earlier on Stevie Wonder\'s album Songs in the Key of Life. The album Gangsta\'s Paradise was released in 1995 and was certified 2X Platinum by the RIAA. The album contained two other major hits in "1, 2, 3, 4 (Sumpin\' New)" and "Too Hot" with J.T. Taylor of Kool & the Gang doing the chorus. Despite no longer being an official member of the group, Coolio made an appearance on the second WC and the Maad Circle album Curb Servin\', on the song "In a Twist". In 1996, Coolio had another top 40 hit with the song "It\'s All the Way Live (Now)" from the soundtrack to the movie Eddie. He was also featured on the song "Hit \'em High" from the soundtrack to the movie Space Jam with B-Real, Method Man, LL Cool J, and Busta Rhymes.  In 2014, the band Falling in Reverse did a cover of "Gangster\'s Paradise" for "Punk Goes 90\'s", with Coolio making a cameo in the music video. ',
#  'qa': [{'question': "What was the relationship between Coolio and Gangsta's parapdise?",
#    'answer': 'Coolio made a song featuring R&B singer LV for the movie Dangerous Minds, titled "Gangsta\'s Paradise',
#    'answer_start': 9},
#   {'question': 'WHen was the song released?',
#    'answer': 'In 1995,',
#    'answer_start': 0},
#   {'question': 'Which record label release the song?',
#    'answer': 'RIAA.',
#    'answer_start': 1217},
#   {'question': 'Did the song have a high sales?',
#    'answer': 'It would become one of the most successful rap songs of all time, reaching #1 on the Billboard Hot 100 for 3 weeks.',
#    'answer_start': 112},
#   {'question': 'Did he wind any award?',
#    'answer': 'At the 1996 Grammy Awards, the song won Coolio a Grammy for Best Rap Solo Performance.',
#    'answer_start': 655},
#   {'question': 'Which other names were mention n the song?',
#    'answer': 'Too Hot" with J.T. Taylor of Kool & the Gang doing the chorus.',
#    'answer_start': 1299},
#   {'question': 'What was their contribution to the song?',
#    'answer': 'J.T. Taylor of Kool & the Gang doing the chorus.',
#    'answer_start': 1313},
#   {'question': 'Which other song did he make?',
#    'answer': "Sumpin' New",
#    'answer_start': 1280}]}

# %%
# randomly select one article to test your code

idx = 5

text = data[idx]["text"]
text

qs = [item["question"] for item in  data[idx]['qa']]
qs

ans =[item["answer"] for item in  data[idx]['qa']]
ans
# Out:
# 'In 1995, Coolio made a song featuring R&B singer LV for the movie Dangerous Minds, titled "Gangsta\'s Paradise". It would become one of the most successful rap songs of all time, reaching #1 on the Billboard Hot 100 for 3 weeks. It was the #1 single of 1995 for all genres, and was a global hit, as it reached #1 in the United States, United Kingdom, Ireland, France, Germany, Italy, Sweden, Austria, Netherlands, Norway, Switzerland, Australia, and New Zealand. The song also created a controversy when Coolio claimed that parody artist "Weird Al" Yankovic had not asked for permission to make his parody of "Gangsta\'s Paradise", titled "Amish Paradise". At the 1996 Grammy Awards, the song won Coolio a Grammy for Best Rap Solo Performance.  Originally "Gangsta\'s Paradise" was not meant to be included on one of Coolio\'s studio albums, but its success led to Coolio not only putting it on his next album but also making it the title track. The title track sampled the chorus and music of the song "Pastime Paradise" by Stevie Wonder, which was recorded nearly 20 years earlier on Stevie Wonder\'s album Songs in the Key of Life. The album Gangsta\'s Paradise was released in 1995 and was certified 2X Platinum by the RIAA. The album contained two other major hits in "1, 2, 3, 4 (Sumpin\' New)" and "Too Hot" with J.T. Taylor of Kool & the Gang doing the chorus. Despite no longer being an official member of the group, Coolio made an appearance on the second WC and the Maad Circle album Curb Servin\', on the song "In a Twist". In 1996, Coolio had another top 40 hit with the song "It\'s All the Way Live (Now)" from the soundtrack to the movie Eddie. He was also featured on the song "Hit \'em High" from the soundtrack to the movie Space Jam with B-Real, Method Man, LL Cool J, and Busta Rhymes.  In 2014, the band Falling in Reverse did a cover of "Gangster\'s Paradise" for "Punk Goes 90\'s", with Coolio making a cameo in the music video. '
# ["What was the relationship between Coolio and Gangsta's parapdise?",
#  'WHen was the song released?',
#  'Which record label release the song?',
#  'Did the song have a high sales?',
#  'Did he wind any award?',
#  'Which other names were mention n the song?',
#  'What was their contribution to the song?',
#  'Which other song did he make?']
# ['Coolio made a song featuring R&B singer LV for the movie Dangerous Minds, titled "Gangsta\'s Paradise',
#  'In 1995,',
#  'RIAA.',
#  'It would become one of the most successful rap songs of all time, reaching #1 on the Billboard Hot 100 for 3 weeks.',
#  'At the 1996 Grammy Awards, the song won Coolio a Grammy for Best Rap Solo Performance.',
#  'Too Hot" with J.T. Taylor of Kool & the Gang doing the chorus.',
#  'J.T. Taylor of Kool & the Gang doing the chorus.',
#  "Sumpin' New"]

# %% [markdown]
# ### **Q2.1.** Tokenize function (3 points)
#
# Define a function `tokenize(doc, lemmatized = True, remove_stopword = True)`  as follows:
#
#    - Take three parameters:
#        - `doc`: an input string (e.g. a question)
#        - `lemmatized`: an optional boolean parameter to indicate if tokens are lemmatized. The default value is True (i.e. tokens are lemmatized).
#        - `remove_stopword`: an optional bookean parameter to remove stop words. The default value is True (i.e. remove stop words).
#    - First split the text into sentences.
#    - Split each sentence into unigrams and also clean up tokens as follows:
#        - if `lemmatized` is turned on, lemmatize all unigrams.
#        - if `remove_stopword` is tuned on, remove all stop words.
#    - Convert all unigrams to the lower case and remove punctuations and empty tokens
#    - Count the frequency of each word in each sentence and save the result into a dictionary (see sample output)
#    - Return the resulting **sentences** and **dictionary** after all the processing.
#
#
# (Hint: you can use spacy package for this task. For reference, check https://spacy.io/api/token#attributes)

# %%
nlp = spacy.load('/Users/thanapoomphatthanaphan/miniconda3/lib/python3.11/site-packages/en_core_web_sm/en_core_web_sm-3.7.1')

# %%
def tokenize(doc, lemmatized=True, remove_stopword=True):

    # Initialize a dictionary and list to store words and sentences, respectively
    vocab, sents = {}, []
    
    # Add your code here
    docs = nlp(doc)
    
    # Iterate to tokenize each sentence
    for i, sent in enumerate(docs.sents):
        temp_dict = defaultdict(int)
        sents.append(sent)
        for token in sent:
            
            # Remove punctuations and space
            if token.is_punct or token.is_space:
                continue
            
            # Check lemma
            if lemmatized:
                text = token.lemma_
            else:
                text = token.text
                
            # Convert to lowercase
            text = text.lower()
            
            # Check and remove stopword
            if remove_stopword:
                if token.is_stop:
                    continue
                else:
                    temp_dict[text] += 1
            else:
                temp_dict[text] += 1
        
        # Store vocab in the dictionary
        vocab[i] = temp_dict
    
    return vocab, sents

# %% [markdown]
# #### Lemmatized=True, remove_stopword=True

# %%
print("1.lemmatized=True, remove_stopword=True\n"), 

# concatenate questions to the text and tokenize together
vocab, sents = tokenize(text + '\n' +' '.join(qs), lemmatized=True, remove_stopword=True)
pp.pprint(vocab)
pp.pprint(sents)
# Out:
# 1.lemmatized=True, remove_stopword=True
# (None,)
# {0: defaultdict(<class 'int'>,
#                 {'1995': 1,
#                  'coolio': 1,
#                  'dangerous': 1,
#                  'feature': 1,
#                  'gangsta': 1,
#                  'lv': 1,
#                  'minds': 1,
#                  'movie': 1,
#                  'paradise': 1,
#                  'r&b': 1,
#                  'singer': 1,
#                  'song': 1,
#                  'title': 1}),
#  1: defaultdict(<class 'int'>,
#                 {'1': 1,
#                  '100': 1,
#                  '3': 1,
#                  'billboard': 1,
#                  'hot': 1,
#                  'rap': 1,
#                  'reach': 1,
#                  'song': 1,
#                  'successful': 1,
#                  'time': 1,
#                  'week': 1}),
#  2: defaultdict(<class 'int'>,
#                 {'1': 2,
#                  '1995': 1,
#                  'australia': 1,
#                  'austria': 1,
#                  'france': 1,
#                  'genre': 1,
#                  'germany': 1,
#                  'global': 1,
#                  'hit': 1,
#                  'ireland': 1,
#                  'italy': 1,
#                  'kingdom': 1,
#                  'netherlands': 1,
#                  'new': 1,
#                  'norway': 1,
#                  'reach': 1,
#                  'single': 1,
#                  'states': 1,
#                  'sweden': 1,
#                  'switzerland': 1,
#                  'united': 2,
#                  'zealand': 1}),
#  3: defaultdict(<class 'int'>,
#                 {'al': 1,
#                  'amish': 1,
#                  'artist': 1,
#                  'ask': 1,
#                  'claim': 1,
#                  'controversy': 1,
#                  'coolio': 1,
#                  'create': 1,
#                  'gangsta': 1,
#                  'paradise': 2,
#                  'parody': 2,
#                  'permission': 1,
#                  'song': 1,
#                  'title': 1,
#                  'weird': 1,
#                  'yankovic': 1}),
#  4: defaultdict(<class 'int'>,
#                 {'1996': 1,
#                  'awards': 1,
#                  'best': 1,
#                  'coolio': 1,
#                  'grammy': 2,
#                  'performance': 1,
#                  'rap': 1,
#                  'solo': 1,
#                  'song': 1,
#                  'win': 1}),
#  5: defaultdict(<class 'int'>,
#                 {'album': 2,
#                  'coolio': 2,
#                  'gangsta': 1,
#                  'include': 1,
#                  'lead': 1,
#                  'make': 1,
#                  'mean': 1,
#                  'originally': 1,
#                  'paradise': 1,
#                  'put': 1,
#                  'studio': 1,
#                  'success': 1,
#                  'title': 1,
#                  'track': 1}),
#  6: defaultdict(<class 'int'>,
#                 {'20': 1,
#                  'album': 1,
#                  'chorus': 1,
#                  'early': 1,
#                  'key': 1,
#                  'life': 1,
#                  'music': 1,
#                  'nearly': 1,
#                  'paradise': 1,
#                  'pastime': 1,
#                  'record': 1,
#                  'sample': 1,
#                  'song': 1,
#                  'songs': 1,
#                  'stevie': 2,
#                  'title': 1,
#                  'track': 1,
#                  'wonder': 2,
#                  'year': 1}),
#  7: defaultdict(<class 'int'>,
#                 {'1995': 1,
#                  '2x': 1,
#                  'album': 1,
#                  'certify': 1,
#                  'gangsta': 1,
#                  'paradise': 1,
#                  'platinum': 1,
#                  'release': 1,
#                  'riaa': 1}),
#  8: defaultdict(<class 'int'>,
#                 {'1': 1,
#                  '2': 1,
#                  '3': 1,
#                  '4': 1,
#                  'album': 1,
#                  'chorus': 1,
#                  'contain': 1,
#                  'gang': 1,
#                  'hit': 1,
#                  'hot': 1,
#                  'j.t.': 1,
#                  'kool': 1,
#                  'major': 1,
#                  'new': 1,
#                  'sumpin': 1,
#                  'taylor': 1}),
#  9: defaultdict(<class 'int'>,
#                 {'album': 1,
#                  'appearance': 1,
#                  'circle': 1,
#                  'coolio': 1,
#                  'curb': 1,
#                  'despite': 1,
#                  'group': 1,
#                  'long': 1,
#                  'maad': 1,
#                  'member': 1,
#                  'official': 1,
#                  'second': 1,
#                  'servin': 1,
#                  'song': 1,
#                  'twist': 1,
#                  'wc': 1}),
#  10: defaultdict(<class 'int'>,
#                  {'1996': 1,
#                   '40': 1,
#                   'coolio': 1,
#                   'eddie': 1,
#                   'hit': 1,
#                   'live': 1,
#                   'movie': 1,
#                   'song': 1,
#                   'soundtrack': 1,
#                   'way': 1}),
#  11: defaultdict(<class 'int'>,
#                  {'b': 1,
#                   'busta': 1,
#                   'cool': 1,
#                   'feature': 1,
#                   'high': 1,
#                   'hit': 1,
#                   'j': 1,
#                   'jam': 1,
#                   'll': 1,
#                   'man': 1,
#                   'method': 1,
#                   'movie': 1,
#                   'real': 1,
#                   'rhymes': 1,
#                   'song': 1,
#                   'soundtrack': 1,
#                   'space': 1,
#                   'them': 1}),
#  12: defaultdict(<class 'int'>,
#                  {'2014': 1,
#                   '90': 1,
#                   'band': 1,
#                   'cameo': 1,
#                   'coolio': 1,
#                   'cover': 1,
#                   'fall': 1,
#                   'gangster': 1,
#                   'go': 1,
#                   'make': 1,
#                   'music': 1,
#                   'paradise': 1,
#                   'punk': 1,
#                   'reverse': 1,
#                   'video': 1}),
#  13: defaultdict(<class 'int'>,
#                  {'coolio': 1,
#                   'gangsta': 1,
#                   'parapdise': 1,
#                   'relationship': 1}),
#  14: defaultdict(<class 'int'>, {'song': 1, 'release': 1}),
#  15: defaultdict(<class 'int'>,
#                  {'label': 1,
#                   'record': 1,
#                   'release': 1,
#                   'song': 1}),
#  16: defaultdict(<class 'int'>, {'song': 1, 'high': 1, 'sale': 1}),
#  17: defaultdict(<class 'int'>, {'wind': 1, 'award': 1}),
#  18: defaultdict(<class 'int'>, {'name': 1, 'mention': 1, 'n': 1, 'song': 1}),
#  19: defaultdict(<class 'int'>, {'contribution': 1, 'song': 1}),
#  20: defaultdict(<class 'int'>, {'song': 1})}
# [In 1995, Coolio made a song featuring R&B singer LV for the movie Dangerous Minds, titled "Gangsta's Paradise".,
#  It would become one of the most successful rap songs of all time, reaching #1 on the Billboard Hot 100 for 3 weeks.,
#  It was the #1 single of 1995 for all genres, and was a global hit, as it reached #1 in the United States, United Kingdom, Ireland, France, Germany, Italy, Sweden, Austria, Netherlands, Norway, Switzerland, Australia, and New Zealand.,
#  The song also created a controversy when Coolio claimed that parody artist "Weird Al" Yankovic had not asked for permission to make his parody of "Gangsta's Paradise", titled "Amish Paradise".,
#  At the 1996 Grammy Awards, the song won Coolio a Grammy for Best Rap Solo Performance.  ,
#  Originally "Gangsta's Paradise" was not meant to be included on one of Coolio's studio albums, but its success led to Coolio not only putting it on his next album but also making it the title track.,
#  The title track sampled the chorus and music of the song "Pastime Paradise" by Stevie Wonder, which was recorded nearly 20 years earlier on Stevie Wonder's album Songs in the Key of Life.,
#  The album Gangsta's Paradise was released in 1995 and was certified 2X Platinum by the RIAA.,
#  The album contained two other major hits in "1, 2, 3, 4 (Sumpin' New)" and "Too Hot" with J.T. Taylor of Kool & the Gang doing the chorus.,
#  Despite no longer being an official member of the group, Coolio made an appearance on the second WC and the Maad Circle album Curb Servin', on the song "In a Twist".,
#  In 1996, Coolio had another top 40 hit with the song "It's All the Way Live (Now)" from the soundtrack to the movie Eddie.,
#  He was also featured on the song "Hit 'em High" from the soundtrack to the movie Space Jam with B-Real, Method Man, LL Cool J, and Busta Rhymes.  ,
#  In 2014, the band Falling in Reverse did a cover of "Gangster's Paradise" for "Punk Goes 90's", with Coolio making a cameo in the music video.
# ,
#  What was the relationship between Coolio and Gangsta's parapdise?,
#  WHen was the song released?,
#  Which record label release the song?,
#  Did the song have a high sales?,
#  Did he wind any award?,
#  Which other names were mention n the song?,
#  What was their contribution to the song?,
#  Which other song did he make?]

# %% [markdown]
# #### Lemmatized=True, remove_stopword=False

# %%
# Test another configuration
print("2.lemmatized=True, remove_stopword=False\n"), 
vocab, sents = tokenize(text + '\n' +' '.join(qs), lemmatized=True, remove_stopword=False)
pp.pprint(vocab)
# Out:
# 2.lemmatized=True, remove_stopword=False
# (None,)
# {0: defaultdict(<class 'int'>,
#                 {"'s": 1,
#                  '1995': 1,
#                  'a': 1,
#                  'coolio': 1,
#                  'dangerous': 1,
#                  'feature': 1,
#                  'for': 1,
#                  'gangsta': 1,
#                  'in': 1,
#                  'lv': 1,
#                  'make': 1,
#                  'minds': 1,
#                  'movie': 1,
#                  'paradise': 1,
#                  'r&b': 1,
#                  'singer': 1,
#                  'song': 1,
#                  'the': 1,
#                  'title': 1}),
#  1: defaultdict(<class 'int'>,
#                 {'1': 1,
#                  '100': 1,
#                  '3': 1,
#                  'all': 1,
#                  'become': 1,
#                  'billboard': 1,
#                  'for': 1,
#                  'hot': 1,
#                  'it': 1,
#                  'most': 1,
#                  'of': 2,
#                  'on': 1,
#                  'one': 1,
#                  'rap': 1,
#                  'reach': 1,
#                  'song': 1,
#                  'successful': 1,
#                  'the': 2,
#                  'time': 1,
#                  'week': 1,
#                  'would': 1}),
#  2: defaultdict(<class 'int'>,
#                 {'1': 2,
#                  '1995': 1,
#                  'a': 1,
#                  'all': 1,
#                  'and': 2,
#                  'as': 1,
#                  'australia': 1,
#                  'austria': 1,
#                  'be': 2,
#                  'for': 1,
#                  'france': 1,
#                  'genre': 1,
#                  'germany': 1,
#                  'global': 1,
#                  'hit': 1,
#                  'in': 1,
#                  'ireland': 1,
#                  'it': 2,
#                  'italy': 1,
#                  'kingdom': 1,
#                  'netherlands': 1,
#                  'new': 1,
#                  'norway': 1,
#                  'of': 1,
#                  'reach': 1,
#                  'single': 1,
#                  'states': 1,
#                  'sweden': 1,
#                  'switzerland': 1,
#                  'the': 2,
#                  'united': 2,
#                  'zealand': 1}),
#  3: defaultdict(<class 'int'>,
#                 {"'s": 1,
#                  'a': 1,
#                  'al': 1,
#                  'also': 1,
#                  'amish': 1,
#                  'artist': 1,
#                  'ask': 1,
#                  'claim': 1,
#                  'controversy': 1,
#                  'coolio': 1,
#                  'create': 1,
#                  'for': 1,
#                  'gangsta': 1,
#                  'have': 1,
#                  'his': 1,
#                  'make': 1,
#                  'not': 1,
#                  'of': 1,
#                  'paradise': 2,
#                  'parody': 2,
#                  'permission': 1,
#                  'song': 1,
#                  'that': 1,
#                  'the': 1,
#                  'title': 1,
#                  'to': 1,
#                  'weird': 1,
#                  'when': 1,
#                  'yankovic': 1}),
#  4: defaultdict(<class 'int'>,
#                 {'1996': 1,
#                  'a': 1,
#                  'at': 1,
#                  'awards': 1,
#                  'best': 1,
#                  'coolio': 1,
#                  'for': 1,
#                  'grammy': 2,
#                  'performance': 1,
#                  'rap': 1,
#                  'solo': 1,
#                  'song': 1,
#                  'the': 2,
#                  'win': 1}),
#  5: defaultdict(<class 'int'>,
#                 {"'s": 2,
#                  'album': 2,
#                  'also': 1,
#                  'be': 2,
#                  'but': 2,
#                  'coolio': 2,
#                  'gangsta': 1,
#                  'his': 1,
#                  'include': 1,
#                  'it': 2,
#                  'its': 1,
#                  'lead': 1,
#                  'make': 1,
#                  'mean': 1,
#                  'next': 1,
#                  'not': 2,
#                  'of': 1,
#                  'on': 2,
#                  'one': 1,
#                  'only': 1,
#                  'originally': 1,
#                  'paradise': 1,
#                  'put': 1,
#                  'studio': 1,
#                  'success': 1,
#                  'the': 1,
#                  'title': 1,
#                  'to': 2,
#                  'track': 1}),
#  6: defaultdict(<class 'int'>,
#                 {"'s": 1,
#                  '20': 1,
#                  'album': 1,
#                  'and': 1,
#                  'be': 1,
#                  'by': 1,
#                  'chorus': 1,
#                  'early': 1,
#                  'in': 1,
#                  'key': 1,
#                  'life': 1,
#                  'music': 1,
#                  'nearly': 1,
#                  'of': 2,
#                  'on': 1,
#                  'paradise': 1,
#                  'pastime': 1,
#                  'record': 1,
#                  'sample': 1,
#                  'song': 1,
#                  'songs': 1,
#                  'stevie': 2,
#                  'the': 4,
#                  'title': 1,
#                  'track': 1,
#                  'which': 1,
#                  'wonder': 2,
#                  'year': 1}),
#  7: defaultdict(<class 'int'>,
#                 {"'s": 1,
#                  '1995': 1,
#                  '2x': 1,
#                  'album': 1,
#                  'and': 1,
#                  'be': 2,
#                  'by': 1,
#                  'certify': 1,
#                  'gangsta': 1,
#                  'in': 1,
#                  'paradise': 1,
#                  'platinum': 1,
#                  'release': 1,
#                  'riaa': 1,
#                  'the': 2}),
#  8: defaultdict(<class 'int'>,
#                 {'1': 1,
#                  '2': 1,
#                  '3': 1,
#                  '4': 1,
#                  'album': 1,
#                  'and': 1,
#                  'chorus': 1,
#                  'contain': 1,
#                  'do': 1,
#                  'gang': 1,
#                  'hit': 1,
#                  'hot': 1,
#                  'in': 1,
#                  'j.t.': 1,
#                  'kool': 1,
#                  'major': 1,
#                  'new': 1,
#                  'of': 1,
#                  'other': 1,
#                  'sumpin': 1,
#                  'taylor': 1,
#                  'the': 3,
#                  'too': 1,
#                  'two': 1,
#                  'with': 1}),
#  9: defaultdict(<class 'int'>,
#                 {'a': 1,
#                  'album': 1,
#                  'an': 2,
#                  'and': 1,
#                  'appearance': 1,
#                  'be': 1,
#                  'circle': 1,
#                  'coolio': 1,
#                  'curb': 1,
#                  'despite': 1,
#                  'group': 1,
#                  'in': 1,
#                  'long': 1,
#                  'maad': 1,
#                  'make': 1,
#                  'member': 1,
#                  'no': 1,
#                  'of': 1,
#                  'official': 1,
#                  'on': 2,
#                  'second': 1,
#                  'servin': 1,
#                  'song': 1,
#                  'the': 4,
#                  'twist': 1,
#                  'wc': 1}),
#  10: defaultdict(<class 'int'>,
#                  {'1996': 1,
#                   '40': 1,
#                   'all': 1,
#                   'another': 1,
#                   'be': 1,
#                   'coolio': 1,
#                   'eddie': 1,
#                   'from': 1,
#                   'have': 1,
#                   'hit': 1,
#                   'in': 1,
#                   'it': 1,
#                   'live': 1,
#                   'movie': 1,
#                   'now': 1,
#                   'song': 1,
#                   'soundtrack': 1,
#                   'the': 4,
#                   'to': 1,
#                   'top': 1,
#                   'way': 1,
#                   'with': 1}),
#  11: defaultdict(<class 'int'>,
#                  {'also': 1,
#                   'and': 1,
#                   'b': 1,
#                   'be': 1,
#                   'busta': 1,
#                   'cool': 1,
#                   'feature': 1,
#                   'from': 1,
#                   'he': 1,
#                   'high': 1,
#                   'hit': 1,
#                   'j': 1,
#                   'jam': 1,
#                   'll': 1,
#                   'man': 1,
#                   'method': 1,
#                   'movie': 1,
#                   'on': 1,
#                   'real': 1,
#                   'rhymes': 1,
#                   'song': 1,
#                   'soundtrack': 1,
#                   'space': 1,
#                   'the': 3,
#                   'them': 1,
#                   'to': 1,
#                   'with': 1}),
#  12: defaultdict(<class 'int'>,
#                  {"'s": 2,
#                   '2014': 1,
#                   '90': 1,
#                   'a': 2,
#                   'band': 1,
#                   'cameo': 1,
#                   'coolio': 1,
#                   'cover': 1,
#                   'do': 1,
#                   'fall': 1,
#                   'for': 1,
#                   'gangster': 1,
#                   'go': 1,
#                   'in': 3,
#                   'make': 1,
#                   'music': 1,
#                   'of': 1,
#                   'paradise': 1,
#                   'punk': 1,
#                   'reverse': 1,
#                   'the': 2,
#                   'video': 1,
#                   'with': 1}),
#  13: defaultdict(<class 'int'>,
#                  {"'s": 1,
#                   'and': 1,
#                   'be': 1,
#                   'between': 1,
#                   'coolio': 1,
#                   'gangsta': 1,
#                   'parapdise': 1,
#                   'relationship': 1,
#                   'the': 1,
#                   'what': 1}),
#  14: defaultdict(<class 'int'>,
#                  {'be': 1,
#                   'release': 1,
#                   'song': 1,
#                   'the': 1,
#                   'when': 1}),
#  15: defaultdict(<class 'int'>,
#                  {'label': 1,
#                   'record': 1,
#                   'release': 1,
#                   'song': 1,
#                   'the': 1,
#                   'which': 1}),
#  16: defaultdict(<class 'int'>,
#                  {'a': 1,
#                   'do': 1,
#                   'have': 1,
#                   'high': 1,
#                   'sale': 1,
#                   'song': 1,
#                   'the': 1}),
#  17: defaultdict(<class 'int'>,
#                  {'any': 1,
#                   'award': 1,
#                   'do': 1,
#                   'he': 1,
#                   'wind': 1}),
#  18: defaultdict(<class 'int'>,
#                  {'be': 1,
#                   'mention': 1,
#                   'n': 1,
#                   'name': 1,
#                   'other': 1,
#                   'song': 1,
#                   'the': 1,
#                   'which': 1}),
#  19: defaultdict(<class 'int'>,
#                  {'be': 1,
#                   'contribution': 1,
#                   'song': 1,
#                   'the': 1,
#                   'their': 1,
#                   'to': 1,
#                   'what': 1}),
#  20: defaultdict(<class 'int'>,
#                  {'do': 1,
#                   'he': 1,
#                   'make': 1,
#                   'other': 1,
#                   'song': 1,
#                   'which': 1})}

# %% [markdown]
# ### **Q2.2.** Compute TF-IDF (1 point)
#
# Define a function `compute_tf_idf(vocab)` as follows:
#
# - Take the dictionary returned in Q2.1 as an input.
# - Calculate tf_idf weights as shown in lecture notes (Hint: feel free to reuse the code segment in NLP Lecture Notes (II))
# - Return the smoothed normalized `tf_idf` array and the words corresponding to the columns of the tfidf array.

# %%
def compute_tfidf(vocab):
     
    # add your code here
    # Get document-term matrix
    dtm = pd.DataFrame.from_dict(vocab, orient="index")
    dtm = dtm.fillna(0)
    dtm = dtm.sort_index(axis = 0)
      
    # Get normalized term frequency (tf) matrix        
    tf = dtm.values
    doc_len = tf.sum(axis=1, keepdims=True)
    tf = np.divide(tf, doc_len)
    
    # Get idf
    df = np.where(tf>0, 1, 0)
    smoothed_idf = np.log(np.divide(len(vocab)+1, np.sum(df, axis=0)+1)) + 1    
    smoothed_tf_idf = tf * smoothed_idf
 
    # Get the words corresponding to the columns of the tfidf array
    words = dtm.columns
    
    return smoothed_tf_idf, words

# %%
tfidf, words = compute_tfidf(vocab)

# show shape of tfidf matrix
tfidf.shape
# Out:
# (21, 150)

# %% [markdown]
# ### **Q2.3.** Put everything together to match questions and answers. (4 points)
#
#
# Define a function `Match(text, questions, lemmatized = True, remove_stopword = True, top-K = 3)`  as follows:
# - Take four inputs:
#     - `text`: a paragraph
#    - `questions`: is a list of questions
#    - `lemmatized, remove_stopword`:  similar to those defined in Q2.1
#    - `top-K`: the top-K answer to each question
# - Tokenize the concatenated text and questions using the `tokenize` function as defined in Q2.1.
# - Calculate the smoothed normalized tf_idf matrix for the concatenated text
# - Split the tf_idf matrix into sub-matrices for the text and questions respectively
# - For each question, find the top-K sentences that may answer it based on the TF-IDF similarities between the question and the sentences
# - Return the matched top-K sentences of each question.
#
#
# **Analysis (1 point)**
#
#
# You may find TFIDF similarity may not be able to find correct answers to some questions. Based on your analysis, answer the following questions:
# - What kind of questions cannot be correctly found by this method?
# - What could be the possible solution to fix these issues? Discuss your idea. You don't have to implement it.

# %%
from sklearn.metrics.pairwise import cosine_similarity

def Match(text, questions, lemmatized=True, remove_stopword=True, topK=3):

    
    # Tokenize the concatenated text and questions using the tokenize function as defined in Q2.1
    vocab, sents = tokenize(text + '\n' + ' '.join(questions), lemmatized, remove_stopword)
    
    # Calculate the smoothed normalized tf_idf matrix for the concatenated text
    tfidf, words = compute_tfidf(vocab)
    
    # Split the tf-idf matrix into sub-matrices for the text and questions respectively
    tfidf_text = tfidf[:len(vocab)-len(questions)]
    tfidf_questions = tfidf[len(vocab)-len(questions):]
    
    # Initialize the list to store the top-K sentences
    answers = []
    
    # Iterate over each question
    for idx in range(len(questions)):
        
        # Initialize the temporary list to store the answers for the current question
        temp_ans = []
        
        # Calculate cosine similarity between question and text sentences
        similarities = cosine_similarity(tfidf_questions[idx].reshape(1, -1), tfidf_text)
        
        # Get indices of top-K similar sentences
        top_idx_sim_sents = np.argsort(similarities)[0][::-1][:topK]
        
        # Get top-K sentences for the current question
        for i in top_idx_sim_sents:
            temp_ans.append(sents[i])
        
        # Store the answers for the current question in the list named 'answers'
        answers.append(temp_ans)
    
    return answers

# %%
answers = Match(text, qs, lemmatized=True, remove_stopword=True)

for q, a1, a2 in zip(qs, answers, ans):
    print(f'Q:\t{q}\n\nA:\t{a1}\n\nCorrect:\t{a2}\n')
# Out:
# Q:	What was the relationship between Coolio and Gangsta's parapdise?
#
# A:	[Originally "Gangsta's Paradise" was not meant to be included on one of Coolio's studio albums, but its success led to Coolio not only putting it on his next album but also making it the title track., In 1995, Coolio made a song featuring R&B singer LV for the movie Dangerous Minds, titled "Gangsta's Paradise"., The song also created a controversy when Coolio claimed that parody artist "Weird Al" Yankovic had not asked for permission to make his parody of "Gangsta's Paradise", titled "Amish Paradise".]
#
# Correct:	Coolio made a song featuring R&B singer LV for the movie Dangerous Minds, titled "Gangsta's Paradise
#
# Q:	WHen was the song released?
#
# A:	[The album Gangsta's Paradise was released in 1995 and was certified 2X Platinum by the RIAA., In 1996, Coolio had another top 40 hit with the song "It's All the Way Live (Now)" from the soundtrack to the movie Eddie., It would become one of the most successful rap songs of all time, reaching #1 on the Billboard Hot 100 for 3 weeks.]
#
# Correct:	In 1995,
#
# Q:	Which record label release the song?
#
# A:	[The album Gangsta's Paradise was released in 1995 and was certified 2X Platinum by the RIAA., The title track sampled the chorus and music of the song "Pastime Paradise" by Stevie Wonder, which was recorded nearly 20 years earlier on Stevie Wonder's album Songs in the Key of Life., In 1996, Coolio had another top 40 hit with the song "It's All the Way Live (Now)" from the soundtrack to the movie Eddie.]
#
# Correct:	RIAA.
#
# Q:	Did the song have a high sales?
#
# A:	[He was also featured on the song "Hit 'em High" from the soundtrack to the movie Space Jam with B-Real, Method Man, LL Cool J, and Busta Rhymes.  , In 1996, Coolio had another top 40 hit with the song "It's All the Way Live (Now)" from the soundtrack to the movie Eddie., It would become one of the most successful rap songs of all time, reaching #1 on the Billboard Hot 100 for 3 weeks.]
#
# Correct:	It would become one of the most successful rap songs of all time, reaching #1 on the Billboard Hot 100 for 3 weeks.
#
# Q:	Did he wind any award?
#
# A:	[In 2014, the band Falling in Reverse did a cover of "Gangster's Paradise" for "Punk Goes 90's", with Coolio making a cameo in the music video.
# , He was also featured on the song "Hit 'em High" from the soundtrack to the movie Space Jam with B-Real, Method Man, LL Cool J, and Busta Rhymes.  , In 1996, Coolio had another top 40 hit with the song "It's All the Way Live (Now)" from the soundtrack to the movie Eddie.]
#
# Correct:	At the 1996 Grammy Awards, the song won Coolio a Grammy for Best Rap Solo Performance.
#
# Q:	Which other names were mention n the song?
#
# A:	[In 1996, Coolio had another top 40 hit with the song "It's All the Way Live (Now)" from the soundtrack to the movie Eddie., It would become one of the most successful rap songs of all time, reaching #1 on the Billboard Hot 100 for 3 weeks., In 1995, Coolio made a song featuring R&B singer LV for the movie Dangerous Minds, titled "Gangsta's Paradise".]
#
# Correct:	Too Hot" with J.T. Taylor of Kool & the Gang doing the chorus.
#
# Q:	What was their contribution to the song?
#
# A:	[In 1996, Coolio had another top 40 hit with the song "It's All the Way Live (Now)" from the soundtrack to the movie Eddie., It would become one of the most successful rap songs of all time, reaching #1 on the Billboard Hot 100 for 3 weeks., In 1995, Coolio made a song featuring R&B singer LV for the movie Dangerous Minds, titled "Gangsta's Paradise".]
#
# Correct:	J.T. Taylor of Kool & the Gang doing the chorus.
#
# Q:	Which other song did he make?
#
# A:	[In 1996, Coolio had another top 40 hit with the song "It's All the Way Live (Now)" from the soundtrack to the movie Eddie., It would become one of the most successful rap songs of all time, reaching #1 on the Billboard Hot 100 for 3 weeks., In 1995, Coolio made a song featuring R&B singer LV for the movie Dangerous Minds, titled "Gangsta's Paradise".]
#
# Correct:	Sumpin' New

# %% [markdown]
# **What kind of questions cannot be correctly found by this method?**
#
# - The questions that cannot be correctly found by this method are the questions that contain the similar words and do not have the unique words with high tf-idf. For example, questions 6-8 contain the word "song", and they got the exact same top K sentences as their answers.
#
# **What could be the possible solution to fix these issues?**
#
# - We can use pre-trained model to help a model to better understand the context of the sentence.

# %% [markdown]
# ## **Q3.** (Bonus 2 points)
#
#
# Implement a function `match_by_wv(text, questions, lemmatized = True, remove_stopword = True, topK = 3)` to find topK answers to a question by the similarity of word vectors.
# - For each key word in the question, find the best matched word in a candidate answer by the cosine similarity between the word vectors
# - Calculate the match score of the answer as the mean of the cosine similarities of the best match words
# - Return the answers with the topK largest match score.
#
#
# hint: feel free to use pretrained word vectors

# %%
def match_by_wv(text, questions, 
                lemmatized = True, 
                remove_stopword = True, 
                topK = 3):
    
    answers = None
    
    # add your code
    
    return answers
